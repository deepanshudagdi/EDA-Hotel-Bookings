# %% [markdown]
# # **Hotel Booking Analysis**

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_13056\625027241.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ### Dataset Loading

# %%
df=pd.read_csv('Hotel Bookings.csv')

# %%
df2=df.copy()

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# # Data cleaning

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicates=df.duplicated().value_counts()
duplicates
# Out:
# False    87396
# True     31994
# Name: count, dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (87396, 32)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# hotel                                 0
# is_canceled                           0
# lead_time                             0
# arrival_date_year                     0
# arrival_date_month                    0
# arrival_date_week_number              0
# arrival_date_day_of_month             0
# stays_in_weekend_nights               0
# stays_in_week_nights                  0
# adults                                0
# children                              4
# babies                                0
# meal                                  0
# country                             452
# market_segment                        0
# distribution_channel                  0
# is_repeated_guest                     0
# previous_cancellations                0
# previous_bookings_not_canceled        0
# reserved_room_type                    0
# assigned_room_type                    0
# booking_changes                       0
# deposit_type                          0
# ...

# %%
# Visualizing the missing values
missing_percentages = df.isnull().mean() * 100

# Creating a bar plot of missing value percentages
plt.figure(figsize=(10, 6))
missing_percentages.plot(kind='bar')
plt.title('Percentage of Missing Values')
plt.xlabel('Columns')
plt.ylabel('Percentage')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# After plotting the graph of missing values, I came to know that the "company" column had over 85% of its data missing. so decided  to remove this column from further analysis. Additionally, the "agent" column exhibited approximately 18% missing values, while the "country" column showed a relatively lower percentage, with around 2-3% of missing information."children " column has 4 null values

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#         is_canceled     lead_time  arrival_date_year  \
# count  87396.000000  87396.000000       87396.000000
# mean       0.274898     79.891368        2016.210296
# std        0.446466     86.052325           0.686102
# min        0.000000      0.000000        2015.000000
# 25%        0.000000     11.000000        2016.000000
# 50%        0.000000     49.000000        2016.000000
# 75%        1.000000    125.000000        2017.000000
# max        1.000000    737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count              87396.000000               87396.000000
# mean                  26.838334                  15.815541
# std                   13.674572                   8.835146
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   27.000000                  16.000000
# 75%                   37.000000                  23.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# the data description is
#
# hotel : Name of the hotel (Resort Hotel or City Hotel)
#
# is_canceled : If the booking was canceled (1) or not (0)
#
# lead_time : Number of days before the actual arrival of the guests
#
# arrival_date_year : Year of arrival date
#
# arrival_date_month : Month of month arrival date
#
# arrival_date_week_number : Week number of year for arrival date
#
# arrival_date_day_of_month : Day of arrival date
#
# stays_in_weekend_nights : Number of weekend nights (Saturday or Sunday) spent at the hotel by the guests.
#
# stays_in_week_nights : Number of weeknights (Monday to Friday) spent at the hotel by the guests.
#
# adults : Number of adults among guests
#
# children : Number of children among guests
#
# babies : Number of babies among guests
#
# meal : Type of meal booked
#
# country : Country of guests
#
# market_segment : Designation of market segment
#
# distribution_channel : Name of booking distribution channel
#
# is_repeated_guest : If the booking was from a repeated guest (1) or not (0)
#
# previous_cancellations : Number of previous bookings that were cancelled by the customer prior to the current booking
#
# previous_bookings_not_canceled : Number of previous bookings not cancelled by the customer prior to the current booking
#
# reserved_room_type : Code of room type reserved
#
# assigned_room_type : Code of room type assigned
#
# booking_changes : Number of changes/amendments made to the booking
#
# deposit_type : Type of the deposit made by the guest
#
# agent : ID of travel agent who made the booking
#
# company : ID of the company that made the booking
#
# days_in_waiting_list : Number of days the booking was in the waiting list
#
# customer_type : Type of customer, assuming one of four categories
#
# adr : Average Daily Rate, as defined by dividing the sum of all lodging transactions by the total number of staying nights
#
# required_car_parking_spaces : Number of car parking spaces required by the customer
#
# total_of_special_requests : Number of special requests made by the customer
#
# reservation_status : Reservation status (Canceled, Check-Out or No-Show)
#
# reservation_status_date : Date at which the last reservation status was updated

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for column in df.columns:
    unique_values = df[column].unique()
    print(f"Unique values in {column}:")
    print(unique_values)
    print()
# Out:
# Unique values in hotel:
# ['Resort Hotel' 'City Hotel']
#
# Unique values in is_canceled:
# [0 1]
#
# Unique values in lead_time:
# [342 737   7  13  14   0   9  85  75  23  35  68  18  37  12  72 127  78
#   48  60  77  99 118  95  96  69  45  40  15  36  43  70  16 107  47 113
#   90  50  93  76   3   1  10   5  17  51  71  63  62 101   2  81 368 364
#  324  79  21 109 102   4  98  92  26  73 115  86  52  29  30  33  32   8
#  100  44  80  97  64  39  34  27  82  94 110 111  84  66 104  28 258 112
#   65  67  55  88  54 292  83 105 280 394  24 103 366 249  22  91  11 108
#  106  31  87  41 304 117  59  53  58 116  42 321  38  56  49 317   6  57
#   19  25 315 123  46  89  61 312 299 130  74 298 119  20 286 136 129 124
#  327 131 460 140 114 139 122 137 126 120 128 135 150 143 151 132 125 157
#  147 138 156 164 346 159 160 161 333 381 149 154 297 163 314 155 323 340
#  356 142 328 144 336 248 302 175 344 382 146 170 166 338 167 310 148 165
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# The number of missing values in column 'agent' is low compared to the number of rows. So, lets fill the missing values with mode of the column 'agent'.

# %%
# Write your code to make your dataset analysis ready.
df['agent'].fillna(value=df['agent'].mode()[0],inplace=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_13056\3040750402.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['agent'].fillna(value=df['agent'].mode()[0],inplace=True)

# %% [markdown]
# The number of missing values in column 'country' is  low .So, lets fill the missing values with a constant string 'Others'.

# %%
df['country'].fillna(value='others',inplace=True)

df['country'].isnull().sum()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_13056\567443196.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['country'].fillna(value='others',inplace=True)
# 0

# %% [markdown]
# The number of missing values in column 'children' is 4.we can replace these by'0'

# %%
df['children'].fillna(value=0,inplace=True)
df['children'].isnull().sum()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_13056\1484766955.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['children'].fillna(value=0,inplace=True)
# 0

# %% [markdown]
# It is better to drop the column 'company' altogether since the number of missing values is extremely high.

# %%
df.drop(['company'], axis=1, inplace=True, errors='ignore')

# %%
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# null values in "agent" column replaced by its mode value.null in "country" column replaced by string "others".and "children" column's null values are replaced by value 0 .and  the column 'company' dropped since the number of missing values is extremely high

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# # Univariate analysis

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

plt.rcParams['figure.figsize'] = 8,8
labels = df['hotel'].value_counts().index.tolist()
# Convert value counts to list
sizes = df['hotel'].value_counts().tolist()
# As the name suggest, explode will determine how much each section is separated from each other
explode = (0, 0.1)

colors = ['lightgreen','pink']
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',startangle=90, textprops={'fontsize': 14})
# Out:
# ([<matplotlib.patches.Wedge at 0x2649fc9b390>,
# ...
#  [Text(-1.0334002052130253, -0.3769403346229713, 'City Hotel'),
#   Text(1.127345716914242, 0.41120753222079226, 'Resort Hotel')],
#  [Text(-0.5636728392071046, -0.20560381888525703, '61.1%'),
#   Text(0.6576183348666411, 0.2398710604621288, '38.9%')])

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart is a visually appealing way to represent data. It allows viewers to quickly grasp the overall distribution and proportions of different categories. In this case, a pie chart can effectively showcase the relative sizes of the city hotel and resort hotel segments.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It seems that a huge proportion of hotels was city hotel. Resort hotel tend to be on the expensive side and most people will just stick with city hotel.
# Also, resort hotels tend to be appropriate for larger group of people.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Recognizing the perception that resort hotels are more expensive, a business can adjust its pricing strategies accordingly

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
cancelled_counts=df.groupby(['hotel'])['is_canceled'].sum()
cancelled_counts
# Create the bar chart
plt.bar(cancelled_counts.index, cancelled_counts.values)

# Set the chart title and labels
plt.title('Hotel Cancellations by Hotel Type')
plt.xlabel('Hotel')
plt.ylabel('Count of Cancellations')

# Display the chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart allows for a clear visual comparison between different categories, in this case, the canceled and non-canceled bookings. The distinct bars make it easy to compare the counts or proportions of each category, providing a quick and intuitive understanding of the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar chart shows that the cancellation rate in city hotels is higher compared to resort hotel. This indicates that a larger proportion of bookings in city hotels are canceled by customers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The higher cancellation rate in city hotels suggests that there might be specific factors influencing customer decision-making in urban areas. This insight can help hotel management and marketing teams identify areas for improvement and develop strategies to reduce cancellation rates, such as optimizing booking policies, enhancing customer service, or offering incentives to encourage non-cancellation.

# %% [markdown]
# #### Chart - 3

# %%
# Create a countplot to show the distribution of repeated guests
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df, x="is_repeated_guest", palette="Set1")

# Adding custom labels to the legend
ax.legend(title="Legend", labels=["Not Repeated ", "Repeated "])

# Adding labels and title
plt.xlabel("Repeated Guest")
plt.ylabel("Count")
plt.title("Distribution of Repeated Guests")

# Show the plot
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_13056\529545104.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(data=df, x="is_repeated_guest", palette="Set1")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The reason for selecting a countplot is that it is suitable for visualizing the distribution of categorical data, particularly when you want to compare the frequency of two categories (in this case, "Not Repeated" and "Repeated" guests) within a single variable. It provides a clear and concise representation of how many occurrences there are for each category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The countplot shows that the number of "Not Repeated" guests (zero) is significantly higher, at around 80,000.
# In contrast, the number of "Repeated" guests (one) is relatively lower, at around 400.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact: Understanding that there is a significantly higher number of non-repeated guests can inform the hotel's marketing and customer retention strategies. They may want to focus on strategies to attract and retain more repeat customers, such as loyalty programs, special offers, or improved guest experiences. This can lead to increased customer loyalty and potentially higher revenue over time.
#
# ---
#
#
# Negative Growth: While the chart indicates a lower number of
# repeated guests, this alone doesn't necessarily lead to negative
# growth. It highlights an area where the hotel can potentially improve. The negative impact could occur if the hotel doesn't take action to address this imbalance and fails to retain repeat customers. In the long run, if customer retention strategies are not implemented effectively, it may result in missed revenue opportunities and negative growth in customer loyalty.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
import matplotlib.pyplot as plt

# Sample data (you can replace this with your actual data)
total_bookings = 119390  # Total number of bookings in the dataset
cancelled_bookings = 44224  # Number of canceled bookings in the dataset

# Calculate the percentage of canceled bookings
percentage_cancelled = (cancelled_bookings / total_bookings) * 100

# Create a pie chart
labels = ['Canceled', 'Not Canceled']
sizes = [percentage_cancelled, 100 - percentage_cancelled]
colors = ['lightcoral', 'lightskyblue']
explode = (0.1, 0)  # Explode the 'Canceled' slice for emphasis

plt.figure(figsize=(8, 6))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('Percentage of Canceled Bookings')

# Show the pie chart
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The reason for selecting a pie chart is to effectively visualize the proportion of canceled bookings relative to the total bookings as a percentage. Pie charts are useful when you want to represent parts of a whole and show the distribution of a categorical variable (in this case, canceled vs. not canceled bookings)

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pie chart illustrates that the majority of bookings, approximately 63%, are not canceled.
# Conversely, the smaller portion of the pie, approximately 37%, represents the canceled bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact: The insight that the majority of bookings are not canceled (63%) is positive for the business. It indicates that a significant portion of customers honor their bookings, which can contribute to stable revenue for the hotel. This insight can guide resource allocation, staffing, and inventory management decisions.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
import seaborn as sns
import matplotlib.pyplot as plt

# Create a countplot to show the distribution of room types
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x="reserved_room_type", palette="Set1")

# Adding labels and title
plt.xlabel("Room Type")
plt.ylabel("Count")
plt.title("Distribution of Room Types")

# Rotating x-axis labels for better readability (optional)
plt.xticks(rotation=45)

# Show the plot
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_13056\745780167.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="reserved_room_type", palette="Set1")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a countplot or bar chart. This choice is appropriate for visualizing the distribution of room types and comparing the counts of each room type category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Room Type "A" is the most popular among travelers, with approximately 50,000 bookings.
# Room Type "D" has a moderate level of popularity, with a count ranging between 15,000 and 20,000 bookings.
# Room Type "E" is less popular, with around 5,000 bookings.
# All other room types have counts below 5,000 bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Impact: The insights gained from this chart can have a positive business impact. Knowing which room types are more popular among travelers allows the hotel to optimize its room inventory and pricing strategies. For example, they can allocate more resources to maintaining and marketing Room Type "A," potentially increasing revenue. Additionally, understanding the popularity of different room types can guide future room renovations or expansions to meet customer demand.

# %% [markdown]
# #### Chart - 6

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define the mapping dictionary from country codes to full names
country_mapping = {
    "PRT": "Portugal",
    "GBR": "United Kingdom",
    "FRA": "France",
    "ESP": "Spain",
    "DEU": "Germany",
    "ITA": "Italy",
    "IRL": "Ireland",
    "BEL": "Belgium",
    "BRA": "Brazil",
    "NLD": "Netherlands",
}

# Replace country codes with full names in your DataFrame (assuming 'country' is the column name)
df['country'] = df['country'].map(country_mapping)

# Create a countplot to show the distribution of bookings by country
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x="country", palette="Set1", order=df['country'].value_counts().index[:10])

# Adding labels and title
plt.xlabel("Country")
plt.ylabel("Number of Bookings")
plt.title("Bookings by Country (Top 10)")

# Rotating x-axis labels for better readability (optional)
plt.xticks(rotation=45)

# Show the plot
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_13056\3359782073.py:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x="country", palette="Set1", order=df['country'].value_counts().index[:10])

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a bar chart because it effectively represents the number of bookings made from different countries.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Portugal has the most number of guests, with the highest count, indicating that it is the country with the most guests in this dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insight that most of the guests are from Portugal is valuable for business planning. Hotel managers and marketing teams can focus their marketing efforts on Portugal to attract even more guests. This can lead to increased bookings, revenue, and positive business impact.

# %% [markdown]
# #### Chart - 7

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter data for stays between 1 and 20 nights
filtered_stays = df[(df['stays_in_weekend_nights'] + df['stays_in_week_nights']).between(1, 20)]

# Set the style of the plot
sns.set(style="whitegrid")

# Create a bar chart for the filtered stays
plt.figure(figsize=(10, 6))
sns.countplot(data=filtered_stays, x=filtered_stays['stays_in_weekend_nights'] + filtered_stays['stays_in_week_nights'], palette='Set1')

# Adding labels and title
plt.xlabel("Length of Stay (Nights)")
plt.ylabel("Count")
plt.title("Distribution of Length of Stay")

# Show the plot
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_13056\16992346.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=filtered_stays, x=filtered_stays['stays_in_weekend_nights'] + filtered_stays['stays_in_week_nights'], palette='Set1')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a histogram because it effectively represents the distribution of a numerical variable, which is the length of stay

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals that the most common length of stay for guests is between 1 to 4 days, with a peak in this range.
# Longer stays (e.g., 5 to 8 days, 9 to 12 days) have progressively fewer guests, indicating that shorter stays are more common.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Understanding that the most common length of stay is between 1 to 4 days allows the hotel to tailor its services and pricing structures to accommodate this trend. They can focus on efficient turnover of rooms for shorter stays and offer packages that cater to short-term guests, potentially increasing revenue and guest satisfaction.

# %% [markdown]
# #### Chart - 8

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Define the order of months
order = ['January', 'February', 'March', 'April', 'May', 'June',
         'July', 'August', 'September', 'October', 'November', 'December']

# Filter the DataFrame for not canceled bookings (assuming 1 for canceled and 0 for not canceled)
not_canceled_df = df[df['is_canceled'] == 0]

# Group the data by month and count the number of bookings in each month
monthly_counts = not_canceled_df['arrival_date_month'].value_counts().reindex(order)

# Create a line chart to visualize the distribution of not canceled bookings by month
plt.figure(figsize=(12, 6))
plt.plot(monthly_counts.index, monthly_counts.values, marker='o', linestyle='-')
plt.xlabel('Month')
plt.ylabel('Count')
plt.title('Distribution of Not Canceled Bookings by Month')
plt.xticks(rotation=45)
plt.grid(True)  # Add grid lines

# Show the line chart
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a line chart because it effectively displays the trend in the distribution of not canceled bookings across months.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart reveals that the highest number of not canceled bookings occurred in August, followed closely by July. These two months have the highest peaks in the distribution.
# Overall, the chart provides a visual representation of the seasonality in booking patterns, with a peak in the summer months.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Understanding that August and July have the highest number of not canceled bookings can help the hotel allocate resources and plan for increased demand during these peak months.They can offer special promotions, ensure sufficient staff, and optimize pricing strategies to maximize revenue.

# %% [markdown]
# # **Bivariate** **Analysis**

# %% [markdown]
# #### Chart - 9

# %%
import matplotlib.pyplot as plt

# Calculate revenue for each hotel by multiplying ADR by the total number of stays
df['revenue'] = df['adr'] * (df['stays_in_weekend_nights'] + df['stays_in_week_nights'])

# Group by hotel and sum the revenue
hotel_revenue = df.groupby('hotel')['revenue'].sum().reset_index()

# Function to add value labels on top of the bars
def add_value_labels(ax, spacing=5):
    for i, v in enumerate(hotel_revenue['revenue']):
        ax.text(i, v + spacing, round(v, 2), ha='center', va='bottom')

# Create a bar chart to visualize the revenue generated by each hotel
plt.figure(figsize=(10, 6))
ax = plt.gca()
bars = plt.bar(hotel_revenue['hotel'], hotel_revenue['revenue'], color=['skyblue', 'lightgreen'])
plt.xlabel('Hotel')
plt.ylabel('Total Revenue')
plt.title('Total Revenue Generated by Each Hotel')

# Call the function to add value labels
add_value_labels(ax)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart chosen is a bar chart, which is effective for comparing revenue figures between two categories (City Hotel and Resort Hotel).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights from the chart are that the City Hotel generated higher revenue (18,704,101.51) compared to the Resort Hotel (15,686,837.77), despite the City Hotel having a higher number of bookings. This suggests that the City Hotel may have a more efficient revenue generation strategy or higher room rates on average.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The City Hotel can further analyze the factors contributing to its higher revenue and potentially apply these strategies to increase revenue further. However, it's essential to ensure that any changes do not negatively impact customer satisfaction or lead to decreased bookings, as this could have a negative growth impact.

# %% [markdown]
# #### Chart - 10

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the percentage of canceled and not canceled bookings for each hotel type
canceled_percentage = df.groupby(['hotel', 'is_canceled']).size().unstack().fillna(0)
canceled_percentage['Total'] = canceled_percentage.sum(axis=1)
canceled_percentage['Canceled_Percentage'] = (canceled_percentage[1] / canceled_percentage['Total']) * 100
canceled_percentage['Not_Canceled_Percentage'] = (canceled_percentage[0] / canceled_percentage['Total']) * 100

# Create a stacked bar graph
plt.figure(figsize=(10, 6))
sns.barplot(data=canceled_percentage.reset_index(), x='hotel', y='Canceled_Percentage', color='green', label='Canceled')
sns.barplot(data=canceled_percentage.reset_index(), x='hotel', y='Not_Canceled_Percentage', bottom=canceled_percentage['Canceled_Percentage'], color='skyblue', label='Not Canceled')

# Adding labels and title
plt.xlabel('Hotel Type')
plt.ylabel('Percentage')
plt.title('Percentage of Canceled and Non-Canceled Bookings in Each Hotel Type')



# Show the plot with custom legend
custom_legend = [plt.Line2D([0], [0], color='green', lw=4), plt.Line2D([0], [0], color='skyblue', lw=4)]
plt.legend(custom_legend, ['Canceled', 'Not Canceled'])

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose to create a stacked bar chart to visually represent the percentage of bookings that are canceled and not canceled in each type of hotel (City Hotel and Resort Hotel).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights from the chart show that the City Hotel has a higher percentage of cancellations (around 30%) compared to the Resort Hotel (around 22%). This indicates that despite having more bookings, the City Hotel faces a higher cancellation rate.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Insight can lead to a positive business impact if the hotel management takes steps to understand the reasons for these cancellations and implements strategies to reduce them.

# %% [markdown]
# #### Chart - 11

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Calculate the percentage of repeated guests in each hotel
hotel_repeated_guests = df.groupby(['hotel', 'is_repeated_guest']).size().unstack(fill_value=0)
hotel_repeated_guests_percentage = hotel_repeated_guests.div(hotel_repeated_guests.sum(axis=1), axis=0) * 100

# Create a stacked bar graph
ax = hotel_repeated_guests_percentage.plot(kind='bar', stacked=True, figsize=(12, 6))

# Add percentage labels within the bars
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy()
    label_text = f'{height:.2f}%'
    ax.annotate(label_text, (x + width / 2, y + height / 2), ha='center', va='center', fontweight='bold')

# Customize the plot
plt.xlabel('Hotel')
plt.ylabel('Percentage')
plt.title('Percentage of Repeated Guests in Each Hotel')
plt.xticks(rotation='horizontal')
plt.legend(title='Is Repeated Guest', labels=['Not Repeated', 'Repeated'])

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart used was a stacked bar graph that represented the percentage of repeated guests segmented by each hotel type (Resort Hotel and City Hotel).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The percentage of repeated guests in the Resort Hotel is higher (5%) compared to the City Hotel (3%).
# This suggests that the Resort Hotel may have a more loyal customer base, potentially due to the nature of the resort experience or effective loyalty programs.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The hotel can consider implementing strategies to further enhance customer loyalty.

# %% [markdown]
# #### Chart - 12

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filter the DataFrame to include only canceled bookings
canceled_bookings_df = df[df['is_canceled'] == 1]

# Create a bar chart to compare the number of canceled bookings by guest type
plt.figure(figsize=(8, 6))
sns.countplot(data=canceled_bookings_df, x="is_repeated_guest", palette="Set1")

# Adding labels and title
plt.xlabel("Guest Type")
plt.ylabel("Number of Canceled Bookings")
plt.title("Canceled Bookings by Guest Type")

# Customize x-axis labels
plt.xticks([0, 1], ["New Guests", "Repeated Guests"])

# Show the plot
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_13056\1101833430.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=canceled_bookings_df, x="is_repeated_guest", palette="Set1")

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked the specific chart (a bar graph comparing cancellations between repeated and new guests) because it effectively visualizes the comparison of cancellation counts between these two guest types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insight from the chart is that cancellations are predominantly made by new guests, while repeated guests have a significantly lower cancellation rate.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insight can help create a positive business impact by allowing the hotel management to tailor their strategies to reduce cancellations among new guests. This can lead to improved revenue and customer satisfaction.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# Create a new column 'total_stay_days' by summing 'stays_in_weekend_nights' and 'stays_in_week_nights'
df['total_stay_days'] = df['stays_in_weekend_nights'] + df['stays_in_week_nights']

plt.figure(figsize = (12,6))
sns.scatterplot(y = 'total_stay_days', x = 'adr', data =df[df['adr'] < 1000])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart I chose is a scatterplot, which helps visualize the relationship between two numerical variables, Average Daily Rate (ADR) and the total length of stay in nights.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  The chart shows a negative correlation between ADR and the total length of stay. As the ADR increases, the length of stay tends to decrease.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Understanding this relationship can help the hotel management make informed decisions about pricing strategies. They can adjust ADR to optimize revenue based on desired occupancy rates and length of stay.

# %% [markdown]
# #### Chart - 14 - Pair Plot

# %%
# Pair Plot visualization code
import seaborn as sns
import matplotlib.pyplot as plt

# Selecting columns for the pair plot
selected_columns = [
    'lead_time',
    'stays_in_weekend_nights',
    'stays_in_week_nights',
    'adults',
    'children',
    'babies',
    'previous_cancellations',
    'previous_bookings_not_canceled',
    'booking_changes',
    'days_in_waiting_list',
    'adr',
    'required_car_parking_spaces',
    'total_of_special_requests'
]

# Creating a DataFrame with selected columns
selected_df = df[selected_columns]

# Creating the pair plot
sns.pairplot(selected_df)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The specific chart, a pair plot, was chosen because it provides a comprehensive view of the relationships between multiple variables in the dataset. It allows for the visualization of scatterplots for pairs of variables, histograms for individual variables, and correlations in a single display.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# based on the pair plot, there appears to be a positive correlation between the number of "stays_in_weekend_nights" and the number of "stays_in_week_nights." This means that when the number of weekend nights spent at the hotel increases, there is a tendency for the number of weeknights spent at the hotel to also increase. This relationship makes intuitive sense, as guests who choose to stay at a hotel over the weekend might be more likely to extend their stay into the week.
# similarly we can analyse other variables

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
# **Optimize Booking Cancellation Rates:**
#
# The analysis shows that a significant percentage of bookings are canceled. To reduce cancellations, the hotel can implement stricter cancellation policies, offer incentives for non-cancellable bookings, or improve communication with guests to understand their reasons for canceling.
#
# **Revenue Maximization:**
#
# To maximize revenue, the hotel can adjust pricing strategies based on demand trends observed in the dataset. For example, during peak booking periods, prices can be increased, while discounts can be offered during low-demand times.
#
# **Customer Segmentation and Targeting:**
#
# The dataset provides insights into different customer segments. The hotel can use this information for targeted marketing campaigns. For instance, marketing efforts can be tailored to attract more guests from countries with a higher booking rate or to encourage repeated bookings by analyzing previous guest behavior.
#
# **Room Type Management:**
#
# Understanding which room types are more likely to be booked and assigned can help the hotel better manage room inventory. They can optimize room allocation to maximize occupancy and revenue.
#
# **Length of Stay Optimization:**
#
# The analysis shows that most guests stay for 1-4 days. The hotel can create packages or incentives to encourage longer stays, which can increase revenue.
#
# **Customer Satisfaction:**
#
# The hotel can focus on improving customer satisfaction and the guest experience. Satisfied guests are more likely to return and leave positive reviews, which can attract more bookings.
#
# **Revenue Management with ADR:**
#
# The Average Daily Rate (ADR) analysis suggests that higher ADR may lead to fewer nights stayed. The hotel can balance pricing strategies to maximize both ADR and occupancy for optimal revenue.
#
# **Seasonal Pricing:**
#
# The analysis of booking trends by month shows that certain months have higher booking rates. The hotel can adjust pricing and marketing efforts seasonally to take advantage of peak booking periods.
#
# **Distribution Channel Optimization:**
#
# The dataset reveals different distribution channels used by guests. The hotel can analyze the performance of these channels and allocate resources to the most effective ones.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# City Hotel is more preferred than Resort Hotel.
#
# City Hotels have a higher cancellation rate.
#
# The dataset mainly consists of "Not Repeated" guests.
#
# 63% of bookings are not canceled.Around 37% of bookings are canceled.
#
# Room Type "A" is the most popular.
#
# most number of guests are from portugal.
#
# Most guests stay for 1 to 4 days.
#
# August is the busiest month for bookings, while January has the fewest.
#
# City Hotel generates higher revenue.
#
# City Hotel faces a higher cancellation rate.
#
# Resort Hotel has more repeated guests.
#
# New guests tend to cancel more.
#
# Higher ADR correlates with shorter stays.
